# %% [markdown]
# ## Creating a Filter, Edge Detection

# %% [markdown]
# ### Import resources and display Image

# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2

# %matplotlib inline

image = cv2.imread('himani.jpg')

image_copy = np.copy(image)

image_copy = cv2.cvtColor(image_copy, cv2.COLOR_BGR2RGB)

plt.imshow(image_copy)

# %%
# Convert to grayscale
gray = cv2.cvtColor(image_copy, cv2.COLOR_RGB2GRAY)

plt.imshow(gray, cmap='gray')

# %% [markdown]
# ### Create custom kernel

# %%
# 3x3 array for edge detection, vertical not horizontal
# Sobel filter
sobel_x = np.array([[-1, 0, 1],
                  [-2, 0, 2],
                  [-1, 0, 1]])

# Perform convolution : input - (grayscale_image, image, bit-depth, kernel)
filtered_image = cv2.filter2D(gray, -1, sobel_x)

plt.imshow(filtered_image, cmap='gray')

# %% [markdown]
# ### Create a binary image

# %%
# Purely black and white image with strongest edges clearly visible

# Create threshold that sets all the filtered pixels to white
# Above a certain threshold
# filtered_image, low_value_to_set, pixel_to_turn_into, threshold
retval, binary_image = cv2.threshold(filtered_image, 100, 255, cv2.THRESH_BINARY)

plt.imshow(binary_image, cmap='gray')

# %% [markdown]
# ## Gaussian Blur

# %%
# Read in image
# convert to Grayscale 
# params grayscale_image, kernel_size, standard_deviation(automatically calculated if set to 0)
# then use cv2.GaussianBlur(grayscale_image, (5,5), 0)
# then apply sobel filter

# %% [markdown]
# ## Canny Edge detector

# %%
# read in image
# convert to Grayscale

# Define lower and upper thresholds for hysteresis
lower = 120
upper = 240

edges = cv2.Canny(grayscale_image, lower, upper)

# plot edges image
